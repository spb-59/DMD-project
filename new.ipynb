# %%
from wfdb.io import rdrecord

# %%
r=rdrecord('ptb-diagnostic-ecg-database-1.0.0/ptb-diagnostic-ecg-database-1.0.0/patient001/s0010_re')

# %%
from matplotlib import pyplot as plt


df=r.to_dataframe()
sf=r.fs
plt.plot(df['i'][:1000])
df.columns = ['I', 'II', 'III', 'aVR', 'aVL', 'aVF', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'vx', 'vy', 'vz']
plt.plot(df['I'][:1000])

# %%
from denoising import denoise

df=denoise(df,sf)
len(df['I'])/4000
# Out:
# 9.6

# %%
plt.plot(df['I'][:4000])

# %%
from FeatureExtraction import extract

extract(df.to_numpy()[:4000])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[39], line 3
#       1 from FeatureExtraction import extract
# ----> 3 extract(df.to_numpy()[:4000])
#
# File ~/DMD-project/FeatureExtraction.py:88, in extract(signal)
#      84 signal=AugMat(signal.T,200)
#      87 #fit the DMD model
# ---> 88 DMD=dmd.DMD()
#      89 DMD.fit(signal)
#      91 #get the eigenvalue and vectors
#
# File ~/DMD-project/env/lib/python3.12/site-packages/pydmd/dmd.py:60, in DMD.fit(self, X, Y)
#      50 """
#      51 Compute the Dynamic Modes Decomposition to the input data.
#      52
#    (...)
#      57 :type Y: numpy.ndarray or iterable
#      58 """
#      59 self._reset()
# ---> 60 self._snapshots_holder = Snapshots(X)
#      61 n_samples = self.snapshots.shape[1]
#      63 if Y is None:
#
# ...

# %%
r=rdrecord('processed2/1d208b8c-e00a-4a31-96b9-23c3a85c0510')

# %%
from FeatureExtraction import AugMat
r=r.p_signal
r = r[:4000, :12]

# %%
a=AugMat(r.T,200)
r.T.shape
# Out:
# (12, 4000)
