# %%
from wfdb.io import rdrecord


record1=rdrecord('processed3/0c2fba6c-794d-45b5-85b1-e67811c19f37')
record2=rdrecord('processed5/1c89f899-8e84-4fcb-9582-c1f53f38e864')



sig1=record1.to_dataframe()
sig2=record2.to_dataframe()

# %%
import matplotlib.pyplot as plt

plt.plot(sig1['i'][:2000],color='green')
plt.plot(sig2['I'][:1000])
